# %%
import pymongo
import certifi

ca = certifi.where()

# Replace the uri string with your MongoDB deployment's connection string.
conn_str = "mongodb+srv://user123:test123@cluster0.mcwng.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"

# set a 5-second connection timeout
client = pymongo.MongoClient(conn_str, serverSelectionTimeoutMS=5000, tlsCAFile=ca)
try:
    print(client.server_info())
except Exception:
    print("Unable to connect to the server.")
# Out:
# {'version': '5.0.8', 'gitVersion': 'c87e1c23421bf79614baf500fda6622bd90f674e', 'modules': ['enterprise'], 'allocator': 'tcmalloc', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [5, 0, 8, 0], 'openssl': {'running': 'OpenSSL 1.0.1e-fips 11 Feb 2013', 'compiled': 'OpenSSL 1.0.1e-fips 11 Feb 2013'}, 'buildEnvironment': {'distmod': 'rhel70', 'distarch': 'x86_64', 'cc': '/opt/mongodbtoolchain/v3/bin/gcc: gcc (GCC) 8.5.0', 'ccflags': '-Werror -include mongo/platform/basic.h -fasynchronous-unwind-tables -ggdb -Wall -Wsign-compare -Wno-unknown-pragmas -Winvalid-pch -fno-omit-frame-pointer -fno-strict-aliasing -O2 -march=sandybridge -mtune=generic -mprefer-vector-width=128 -Wno-unused-local-typedefs -Wno-unused-function -Wno-deprecated-declarations -Wno-unused-const-variable -Wno-unused-but-set-variable -Wno-missing-braces -fstack-protector-strong -Wa,--nocompress-debug-sections -fno-builtin-memcmp', 'cxx': '/opt/mongodbtoolchain/v3/bin/g++: g++ (GCC) 8.5.0', 'cxxflags'
# ...

# %%
db = client["news"]
collection = db["news_collection"]

news_count = collection.count_documents({})
print(news_count)
# Out:
# 2918

# %%
news_articles = collection.find({ "newsId": "473011" })
for news in news_articles:
    print(news['title'])
    print(news['viewCount'])
    print(news['scrape_time'])
# Out:
# 【4月17日疫情速報】(22:30)
# 220
# 2022-04-18 13:07:38.779000
# 【4月17日疫情速報】(22:30)
# 271
# 2022-04-18 14:53:08.455000
# 【4月17日疫情速報】(22:30)
# 281
# 2022-04-18 23:30:31.229000

# %%
news_articles = collection.find({"viewCount": {"$gte": 100}}).sort("viewCount")
for news in news_articles:
    print("Article title: {}, View Count: {}".format(news['title'], news['viewCount']))
# Out:
# Article title: 李家超：與內地通關是重點努力目標, View Count: 100
# Article title: 林鄭月娥恭賀張家朗升上世界排名第一, View Count: 100
# Article title: 政府：暫有15萬人下載新冠康復紀錄二維碼　有市民無呈報檢測結果遇困難, View Count: 100
# Article title: 首階段放寬社交距離措施　食肆可四人一枱, View Count: 100
# Article title: 黃偉綸：疫情過後社區隔離設施或可改為過渡性房屋, View Count: 100
# Article title: 私家車與電單車將軍澳相撞　電單車司機昏迷送院, View Count: 100
# Article title: 【經緯線】婚禮不似預期（二）, View Count: 101
# Article title: C朗拿度透露兒子的死訊, View Count: 101
# Article title: 本港新增523宗確診　當局密切注視復課後社區傳播風險, View Count: 101
# Article title: 普京稱可實現針對烏克蘭的軍事行動目標　警告會打擊外部干預勢力, View Count: 101
# Article title: 【附名單】黃大仙、九龍城污水檢測結果陽性　政府將向相關人士派發快速測試套裝 (4月17日), View Count: 102
# Article title: 上海當局承認出現轉運患者不及時　會加快建方艙醫院, View Count: 102
# Article title: 分析指若成功佔領頓巴斯　將是普京的安慰獎, View Count: 102
# Article title: 李家超落區探訪基層　倡基層遷入社區配套未完善屋邨, View Count: 102
# Article title: 日本北海道觀光船沉沒　至少10人罹難, View Count: 102
# Article title: 文憑試考生疫情下備戰壓力倍增, View Count: 103
# Article title: 本港增794確診　當局指數字依然高企未恢復追蹤個案, View Count: 103
# ...
