# %%
import pandas as pd
import requests
import time

# %%
ts = str(int(time.time()*1000))

# Response sets cookie: BIGipServerPOOL_SFCAPPS_HTTPS = 'y%8B%A9%EEc.%96d%D2H%0B%5E%98%22%838%D3T%A5w%9B%B1%BC%D3%86%05R515%81%0A%BF%A8%BB%9DY'%E1%ACs%07%7D%1F%05%86%2B%E4%A4%C9-B%7Cm%10%F3%0D%ED%00%00%00%01
response = requests.post("https://apps.sfc.hk/publicregWeb/searchByRaJson",
params={
    "_dc": ts,
},
data={
    "licstatus": "active",
    "roleType": "corporation",
    "ratype": "9",
    "nameStartLetter": "A",
    "page": "1",
    "start": "0",
    "limit": "203",
},
headers={
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    "Connection": "keep-alive",
    "Content-Length": "90",
    "Cookie": "TS0173272d=01ee710898b0d8293b3da119750fbc9bb41504befaece7964ae71f40a0b91a81163d6a1949bb4011d11c41d1612f031163f795434d; JSESSIONID=FFA20D8BE73116BAA32A375E51E5C497; __utma=23669880.487826073.1702289451.1702289452.1702289452.1; __utmc=23669880; __utmz=23669880.1702289452.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); org.springframework.web.servlet.i18n.CookieLocaleResolver.LOCALE=en; _gid=GA1.2.1770966819.1702289485; LICDETAIL_TYPE=all; _ga_PSYEMG5425=GS1.1.1702301611.2.1.1702302021.0.0.0; _ga=GA1.2.487826073.1702289451; TS019a838e=01ee7108980ed124ccbf9238e7e40c6edc28c83dd40c284c79d5727de5d2cc3646feb4df793b99f1b03a4862167cb396e6681a9056; BIGipServerPOOL_SFCAPPS_HTTPS=%1C%2F)%AF%C4fMtE%01%22%0B%5E%98%22%838%D3T%A5w%9B%13%A5%8B%07%87u%C8%BE%E6%8E%83%A9u%DB%0A%F3x%1E%2F%C71%B2%9C%E3)%08%5D%1C7%87i%E8DB8%80%CB%00%00%00%01",
    "Host": "apps.sfc.hk",
    "Origin": "https://apps.sfc.hk",
    "Referer": "https://apps.sfc.hk/publicregWeb/searchByRa",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest",
    "sec-ch-ua": "\"Not_A Brand\";v=\"8\", \"Chromium\";v=\"120\", \"Google Chrome\";v=\"120\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
},
cookies={
    "TS0173272d": "01ee710898b0d8293b3da119750fbc9bb41504befaece7964ae71f40a0b91a81163d6a1949bb4011d11c41d1612f031163f795434d",
    "JSESSIONID": "FFA20D8BE73116BAA32A375E51E5C497",
    "__utma": "23669880.487826073.1702289451.1702289452.1702289452.1",
    "__utmc": "23669880",
    "__utmz": "23669880.1702289452.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)",
    "org.springframework.web.servlet.i18n.CookieLocaleResolver.LOCALE": "en",
    "_gid": "GA1.2.1770966819.1702289485",
    "LICDETAIL_TYPE": "all",
    "_ga_PSYEMG5425": "GS1.1.1702301611.2.1.1702302021.0.0.0",
    "_ga": "GA1.2.487826073.1702289451",
    "TS019a838e": "01ee7108980ed124ccbf9238e7e40c6edc28c83dd40c284c79d5727de5d2cc3646feb4df793b99f1b03a4862167cb396e6681a9056",
    "BIGipServerPOOL_SFCAPPS_HTTPS": "%1C%2F)%AF%C4fMtE%01%22%0B%5E%98%22%838%D3T%A5w%9B%13%A5%8B%07%87u%C8%BE%E6%8E%83%A9u%DB%0A%F3x%1E%2F%C71%B2%9C%E3)%08%5D%1C7%87i%E8DB8%80%CB%00%00%00%01",
})

# %%
response.json()
# Out:
# {'totalCount': 203,
#  'items': [{'ceref': 'AAB444',
#    'name': 'Amundi Hong Kong Limited',
#    'nameChi': '東方匯理資產管理香港有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Suites 04-06, 32nd floor, Two Taikoo Place, Taikoo Place, 979 King's Road, Quarry Bay, Hong Kong, Hong Kong",
#     'fullAddressChin': '香港香港 鰂魚涌英皇道979號 太古坊太古坊二座32樓04-06室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AAD350',
#    'name': 'Anglo Chinese Corporate Finance, Limited',
#    'nameChi': '英高財務顧問有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '40/F Two Exchange Square, 8 Connaught Place, Central, Hong Kong',
#     'fullAddressChin': '香港中環康樂廣場8號交易廣場第2座40樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AAD365',
#    'name': 'Anglo Chinese Securities, Limited',
#    'nameChi': '英高證券有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '40/F Two Exchange Square, 8 Connaught Place, Central, Hong Kong',
#     'fullAddressChin': '香港中環康樂廣場8號交易廣場第2座40樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AAE950',
#    'name': 'abrdn Hong Kong Limited',
#    'nameChi': '安本香港有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "30/F LHT Tower, 31 Queen's Road Central, Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中31號陸海通大廈30樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AAF157',
#    'name': 'Aisance Asset Management Limited',
#    'nameChi': '君達資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 1704A Tower 2 Admiralty Center, 18 Harcourt Road, Admiralty, Hong Kong',
#     'fullAddressChin': '香港金鐘夏愨道18號海富中心第2期1704A室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AAG391',
#    'name': 'Asia Pacific Investment Advisors Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'ROOM 801 & 803  8/F, WON HING BUILDING, 74-78 STANLEY STREET, CENTRAL, Hong Kong',
#     'fullAddressChin': '香港中環士丹利街74-78號旺興大廈8樓801及803室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AAJ958',
#    'name': 'ACM Asia Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "21/F, 168 Queen's Road Central, Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中168號21樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AAK058',
#    'name': 'Associated Advisers Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 903 Chow Sang Sang Building, 229 Nathan Road, Kowloon, Hong Kong',
#     'fullAddressChin': '香港九龍彌敦道 229 號周生生大廈 903室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AAP809',
#    'name': 'AXA Investment Managers Asia Limited',
#    'nameChi': '安盛投資管理亞洲有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Suites 3603-05, One Taikoo Place, Taikoo Place, 979 Kings Road, Quarry Bay, Hong Kong',
#     'fullAddressChin': '香港鰂魚涌太古坊英皇道979號太古坊一座3603-05室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AAZ063',
#    'name': 'Averest Capital Limited',
#    'nameChi': '永桐資本有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 1601-1607 16/F Nan Fung Tower, 88 Connaught Road Central, Central, Hong Kong',
#     'fullAddressChin': '香港中環干諾道中88號南豐大廈16樓1601-07室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ABP316',
#    'name': 'ALPS Advisory (HK) Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '15th Floor The Wellington, 198 Wellington Street, Central, Hong Kong',
#     'fullAddressChin': '香港中環威靈頓街一九八號十五樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ACH601',
#    'name': 'Alpha Nova Capital Management Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Suite 1501, 15/F, Tower 2, The Gateway, Tsim Sha Tsui, Kowloon, Hong Kong',
#     'fullAddressChin': '香港九龍尖沙咀港威大廈第2座15樓1501室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ADC047',
#    'name': 'Allard Partners Limited',
#    'nameChi': '全亞達投資有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 901 9/F Ruttonjee House, 3-11 Duddell Street, Central, Hong Kong',
#     'fullAddressChin': '香港中環都爹利街3-11號律敦治大廈9樓901室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ADC118',
#    'name': 'Axiom Investment Management Limited',
#    'nameChi': '明懿資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Suite 3303, 33/F, Singga Commercial Centre, 144-151 Connaught Road West, Hong Kong',
#     'fullAddressChin': '香港香港干諾道西144-151號成基商業中心3303室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ADU453',
#    'name': 'Asia Investment Research Limited',
#    'nameChi': '亞洲投資研究有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 1262, Level 12, Infinitus Plaza, 199 Des Voeux Road Central, Sheung Wan, Hong Kong',
#     'fullAddressChin': '香港上環德輔道中199號無限極廣場12楼 1262室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ADX555',
#    'name': 'AllianceBernstein Hong Kong Limited',
#    'nameChi': '聯博香港有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '39/F One Island East Taikoo Place, 18 Westlands Road, Quarry Bay, Hong Kong',
#     'fullAddressChin': '香港鰂魚涌華蘭路18號太古坊港島東中心39樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AEE189',
#    'name': 'Access Investment Management (H.K.) Limited',
#    'nameChi': '安信投資管理(香港)有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "21/F LHT Tower, 31 Queen's Road Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中31號陸海通大廈21樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AEN683',
#    'name': 'Asia Debt Management Hong Kong Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Suites 2801-05, Level 28, Three Pacific Place, 1 Queen's Road East, Wanchai, Hong Kong, Hong Kong",
#     'fullAddressChin': '香港皇后大道東1號, 灣仔太古廣場三座2801-05室, 28 樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AFB002',
#    'name': 'Aevitas Securities Limited',
#    'nameChi': '大錦證券有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room B26, 6/F House of Corona, 50 Hung To Road, Kwun Tong Kowloon, Hong Kong',
#     'fullAddressChin': '香港觀塘鴻圖道50號寶冠大廈6樓B26 室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AFB541',
#    'name': 'Avanta Investment Management Limited',
#    'nameChi': '安永達投資管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 33, 5/F United Centre, 95 Queensway, Admiralty, Hong Kong',
#     'fullAddressChin': '香港金鐘金鐘道95號统一中心5樓33室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AFF862',
#    'name': 'Anuenue Advisors Limited',
#    'nameChi': '鉅亨顧問有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '28/F, Guangdong Tours Center, 18 Pennington Street, Causeway Bay, Hong Kong',
#     'fullAddressChin': '香港銅鑼灣邊寧頓街18號廣旅集團大廈28樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AFH256',
#    'name': 'Atlantis Investment Management Limited',
#    'nameChi': '西京投資管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '3501 The Centrium, 60 Wyndham Street, Central, Hong Kong',
#     'fullAddressChin': '香港中環雲咸街60號中央廣場3501室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AFQ783',
#    'name': 'Assured Asset Management Limited',
#    'nameChi': '安誼金融投資股份有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "23/F Arion Commercial Centre, 2-12 Queen's Road West, Sheung Wan, Hong Kong",
#     'fullAddressChin': '香港上環皇后大道西2-12號聯發商業中心23樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AGB171',
#    'name': 'Axis Capital Management Limited',
#    'nameChi': '縱橫資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '18/F, Fortune House, 61 Connaught Road Central, Hong Kong',
#     'fullAddressChin': '香港中環干諾道中61號福興大廈18樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AGD546',
#    'name': 'Asset Dynamic Management Limited',
#    'nameChi': '盈動資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '8/F, Central 88, No. 88-98 Des Voeux Road Central, Central, Hong Kong',
#     'fullAddressChin': '香港中環德輔道中88-98號中環88, 8樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AGH102',
#    'name': 'Altus Capital Limited',
#    'nameChi': '浩德融資有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '21 Wing Wo Street, Central, Hong Kong',
#     'fullAddressChin': '香港中環永和街21號',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AGY047',
#    'name': 'Absolute Investment Management (HK) Limited',
#    'nameChi': '寶橋投資管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 2803-05, 28/F., Tower I, Admiralty Centre, 18 Harcourt Road, Admiralty, Hong Kong',
#     'fullAddressChin': '香港金鐘夏愨道18號海富中心1座28樓2803-05室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AHN919',
#    'name': 'Argyle Street Management Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Unit 601-2  St. George's Building, 2 Ice House Street, Central, Hong Kong",
#     'fullAddressChin': '香港中環雪廠街2號聖佐治大廈601-2室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AHQ867',
#    'name': 'Avia Asset Management Limited',
#    'nameChi': '輝亞資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit A  9/F  Fortis Tower,, 77-79 Gloucester Road, Wanchai, Hong Kong',
#     'fullAddressChin': '香港灣仔告士打道77-79號富通大廈9A',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AIC891',
#    'name': 'Asia Pacific Capital (HK) Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 1421, 14/F Bank of America Tower, 12 Harcourt Road, Central, Hong Kong',
#     'fullAddressChin': '香港中環夏愨道12號美國銀行中心1421室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AJD993',
#    'name': 'Altruist Financial Group Limited',
#    'nameChi': '進邦匯理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '26/F Siu On Plaza, 482 Jaffe Road, Causeway Bay, Hong Kong',
#     'fullAddressChin': '香港香港銅鑼灣謝菲道482號26樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AJE027',
#    'name': 'Aktis Capital Advisory Limited',
#    'nameChi': '瀚曦投資咨詢有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Suite 1707, Tai Yau Building 17/F, 181 Johnston Road, Wan Chai, Hong Kong',
#     'fullAddressChin': '香港灣仔大有大厦17楼1707室香港灣仔莊士敦道181號',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AJF298',
#    'name': 'AlTi Wealth Management (Hong Kong) Limited',
#    'nameChi': '安旗財富管理(香港)有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Room 1802 18/F LHT Tower, 31 Queen's Road Central, Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中31號陸海通大廈18樓1802室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AJN974',
#    'name': 'AD Capital Management (Hong Kong) Limited',
#    'nameChi': '豐盛資產管理(香港)有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit B 11/F Shun Ho Tower, 24-30 Ice House Street, Central, Hong Kong',
#     'fullAddressChin': 'Unit B 11/F Shun Ho Tower, 24-30 Ice House Street, Central, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ALW770',
#    'name': 'AM Squared Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 1602 16/F  LHT Tower, 31 Queens Road Central, Central, Hong Kong',
#     'fullAddressChin': '香港中環皇后大道中31號陸海通大廈16樓1602室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ALY555',
#    'name': 'Astrum Capital Management Limited',
#    'nameChi': '阿仕特朗資本管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 2704, Tower 1, Admiralty Centre, 18 Harcourt Road, Admiralty, Hong Kong',
#     'fullAddressChin': '香港金鐘夏愨道18號海富中心1座2704室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AMP603',
#    'name': 'ARA Asset Management (Prosperity) Limited',
#    'nameChi': '泓富資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 901 Level 9 Fortune Metropolis, 6 The Metropolis Drive, Hunghom Kowloon, Hong Kong',
#     'fullAddressChin': '香港九龍紅磡都會道6號置富都會9樓901室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AMT657',
#    'name': 'Asset Management Group Limited',
#    'nameChi': '資產管理集團有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 02, 40/F, 118 Connaught Road West, Hong Kong',
#     'fullAddressChin': '香港干諾道西一一八號四十樓零二室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ANR899',
#    'name': 'Alpha Wealth Management Limited',
#    'nameChi': '艾法財富管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit B, 15/F, Wah Kit Commercial Centre, 300-302 Des Voeux Road Central, Sheung Wan, Hong Kong',
#     'fullAddressChin': '香港上環德輔道中300-302號華傑商業中心15樓B室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AOA508',
#    'name': 'Abridge Enterprises Company Limited',
#    'nameChi': '合橋企業有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Suite 2401, 24th Floor, Chinachem Exchange Square, Quarry Bay, Hong Kong',
#     'fullAddressChin': '香港鰂魚涌華懋交易廣場24 樓 2401 室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AOR149',
#    'name': 'Abax Global Capital (Hong Kong) Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Units 1707B and 1708 Level 17 International Commerce Centre, 1 Austin Road West, Kowloon, Hong Kong',
#     'fullAddressChin': '香港九龍柯士甸道西1號環球貿易廣場17樓1707B 及1708室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'APB096',
#    'name': 'Aliantis Capital Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '25/F Hysan Place., 500 Hennessy Road, Causeway Bay, Hong Kong',
#     'fullAddressChin': '香港銅鑼灣灣仔軒尼詩道500號希慎廣場25樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'APR560',
#    'name': 'Arta Global Markets Limited',
#    'nameChi': '裕承環球巿場有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Unit 901-02, 9/F, K11 ATELIER King's Road, 728 King's Road, Quarry Bay, Hong Kong",
#     'fullAddressChin': "香港鰂魚涌英皇道 728 號K11 ATELIER King's Road 9樓901-02室",
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AQR074',
#    'name': 'Athena Wealth Management Limited',
#    'nameChi': '智富財富管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '27/F Berkshire House, 25 Westlands Road, Quarry Bay, Hong Kong',
#     'fullAddressChin': '香港鰂魚涌華蘭路25號栢克大廈27樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AQW828',
#    'name': 'Arta Asset Management Limited',
#    'nameChi': '裕承資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Unit 3A, 9/F, K11 ATELIER King's Road, 728 King's Road, Quarry Bay, Hong Kong",
#     'fullAddressChin': "香港鰂魚涌英皇道728號K11 ATELIER King's Road  9樓3A室",
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ARG876',
#    'name': 'Aspen Hill Partners (Hong Kong) Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "10/F St. John's Building, 33 Garden Road, Central, Hong Kong",
#     'fullAddressChin': '香港中環花園道33號聖約翰大廈10樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ARJ340',
#    'name': 'APG Investments Asia Limited',
#    'nameChi': '荷蘭匯盈投資亞洲有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Level 14 and Suites 1505-1509 on Level 15, Three Pacific Place 1 Queen's Road East, Wan Chai, Hong Kong",
#     'fullAddressChin': "Level 14 and Suites 1505-1509 on Level 15, Three Pacific Place 1 Queen's Road East, Wan Chai, Hong Kong",
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ARO976',
#    'name': 'Asia Frontier Investments Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 1805 18/F Hing Yip Commercial Centre, 272-284 Des Voeux Road Central, Sheung Wan, Hong Kong',
#     'fullAddressChin': '香港上環德輔道中272-284號興業商業中心18樓1805室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ARW223',
#    'name': 'ARCH Capital Management Co. Limited',
#    'nameChi': '宏璟資本有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Rooms 1203-05 Champion Tower, 3 Garden Road, Central, Hong Kong',
#     'fullAddressChin': '香港中環花園道3號冠君大廈1203-05室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ASS687',
#    'name': 'Ares Management Asia (Hong Kong) Limited',
#    'nameChi': '群志資本管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "40/F, Gloucester Tower, The Landmark, 15 Queen's Road Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中15 號置地廣場告羅士打大廈40樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'ATB513',
#    'name': 'Ascendant Asset Management (HK) Limited',
#    'nameChi': '景昇資產管理(香港)有限公司 ',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 2503 25/F NEO, 123 Hoi Bun Road, Kwun Tong Kowloon, Hong Kong',
#     'fullAddressChin': '香港九龍觀塘海濱道123號綠景NEO大廈樓2503室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AUL787',
#    'name': 'Apollo Asset Management Limited',
#    'nameChi': '太陽神資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 1603 16/F Tung Ning Building, 125-126 Connaught Road Central, Sheung Wan, Hong Kong',
#     'fullAddressChin': '香港上環干諾道中125-126號東寧大廈16樓1603室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AUU918',
#    'name': 'Austen Capital Management Limited',
#    'nameChi': '鼎豐資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit B, 22/F, Times Tower, 391-407 Jaffe Road, Wanchai, Hong Kong',
#     'fullAddressChin': '香港湾仔谢菲道391-407號新时代中心22 樓B室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AUW716',
#    'name': 'ARA Asset Management (Fortune) Limited',
#    'nameChi': '置富資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'No. 12-01 Suntec Tower Five, 5 Temasek Boulevard, 038985, Singapore',
#     'fullAddressChin': 'No. 12-01 Suntec Tower Five, 5 Temasek Boulevard, 038985, Singapore',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AVO623',
#    'name': 'Areion Asset Management Company Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Unit 1705 17/F Low Block, Grand Millennium Plaza, 181 Queen's Road Central, Sheung Wan, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中181號新紀元廣場低座17樓1705室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AWJ200',
#    'name': 'Asia Alternatives Advisor Hong Kong Limited',
#    'nameChi': '香港亞洲投資咨詢有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 2102, 21/F Nexxus Building, 41 Connaught Road Central, Hong Kong',
#     'fullAddressChin': '香港中環干諾道中41號盈置大廈21 樓2102室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AXC972',
#    'name': 'An Zhong (AZ) Investment Management Hong Kong Limited',
#    'nameChi': '安中投資管理香港有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 3B-5A 19/F The Centrium, 60 Wyndham Street, Central, Hong Kong',
#     'fullAddressChin': '香港中環雲咸街60號中央廣場19樓3B-5A室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AXF933',
#    'name': 'Amber Hill Asset Management Limited',
#    'nameChi': '安山資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Unit No. 4202-05, 42/F, Cosco Tower, 183 Queen's Road, Central, Hong Kong, Hong Kong",
#     'fullAddressChin': "Unit No. 4202-05, 42/F, Cosco Tower, 183 Queen's Road, Central, Hong Kong, Hong Kong",
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AXG299',
#    'name': 'About Capital Management (HK) Co. Ltd',
#    'nameChi': '百域資本(香港)有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "4001 COSCO Tower, 183 Queen's Road Central, Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中183號中遠大廈4001室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AXM315',
#    'name': 'Ant Global Partners (HK) Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Suite 2059, 20F The Lee Gardens Three, 1 Sunning Road, Causeway Bay, Hong Kong',
#     'fullAddressChin': '香港銅鑼灣新寧道1號利園3期20樓2059室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AXN003',
#    'name': 'Azurewing Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit B, 7/F,, Seabright Plaza, 9-23 Shell Street,, North Point,, Hong Kong',
#     'fullAddressChin': '香港北角 蜆殼街 9-23 號秀明中心7樓B室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AYP193',
#    'name': 'Asia Research & Capital Management Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "21 st Floor Shanghai Commercial Bank Tower, 12 Queen's Road, Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中12號上海商業銀行大廈21樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AYR797',
#    'name': 'Ascalon Capital Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 2, Suite 1002, 10/f, Cambridge House, Taikoo Place, 979 Kings Road, Quarry Bay, Hong Kong',
#     'fullAddressChin': 'Room 2, Suite 1002, 10/f, Cambridge House, Taikoo Place, 979 Kings Road, Quarry Bay, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AYT237',
#    'name': 'Athos Capital Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "8th Floor, 8 Queen's Road Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中8號8樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AZC453',
#    'name': 'Avalok Capital Limited',
#    'nameChi': '宏觀資本有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit No. 1110, Level 11, Tower I, Grand Central Plaza, 138 Shatin Rural Committee Road, Shatin, NT, Hong Kong',
#     'fullAddressChin': '香港新界沙田新城市中央廣場1座11樓10室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AZF321',
#    'name': 'Adamas Asset Management (HK) Limited',
#    'nameChi': '安德思資產管理(香港)有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': None,
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AZP140',
#    'name': 'Ariose Capital Management Limited',
#    'nameChi': '弘盛資本有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Suite 505 ICBC Tower, 3 Garden Road, Central, Hong Kong',
#     'fullAddressChin': '香港中環花園道3號中國工商銀行大廈505室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AZP290',
#    'name': 'Alphamax Asset Management (HK) Limited',
#    'nameChi': '利升資產管理(香港)有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Suite 4701, 47/F., Central Plaza, 18 Harbour Road, Wanchai, Hong Kong',
#     'fullAddressChin': '香港灣仔港灣道18號中環廣場47樓4701室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'AZY004',
#    'name': 'Asia Alpha Capital Management Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 15, 4/F, 9 Queens Road Central, Central, Hong Kong',
#     'fullAddressChin': 'Room 15, 4/F, 9 Queens Road Central, Central, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BAA046',
#    'name': 'ABCI Asset Management Limited',
#    'nameChi': '農銀國際資産管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '5/F Agricultural Bank of China Tower, 50 Connaught Road Central, Central, Hong Kong',
#     'fullAddressChin': '香港中環干諾道中50號中國農業銀行大廈5樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BAI353',
#    'name': 'Ascender Capital Limited',
#    'nameChi': '升騰資本有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '3001 W50, 50 Wong Chuk Hang Road, Hong Kong',
#     'fullAddressChin': '香港黃竹坑路50號W50, 30樓01室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BAO325',
#    'name': 'Amital Asset Management  Limited',
#    'nameChi': '安博資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 1204 12/F Jubilee Centre, 18 Fenwick Street, Wanchai, Hong Kong',
#     'fullAddressChin': '香港灣仔分域街18號捷利中心12楼1204室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BBE598',
#    'name': 'Avantua Capital Management Limited',
#    'nameChi': '璟裕資本管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Suites 2503-04, 25/F, K11 ATELIER, 728 King's Road, Quarry Bay, Hong Kong",
#     'fullAddressChin': '香港鰂魚涌英皇道728號K11 ATELIER25樓2503-04室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BBR213',
#    'name': 'Admiral Investment Limited',
#    'nameChi': '安泓投資有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '8/F Kam Shek Commercial Building, 17 Waterloo Road, Yau Ma Tei, Kowloon, Kowloon, Hong Kong',
#     'fullAddressChin': '香港九龍窩打老道17號金石商業大廈8樓',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BBS728',
#    'name': 'Ally Bridge Group (HK) Limited',
#    'nameChi': '滙橋資本集團(香港)有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Room 3002-3004, 30/F, Gloucester Tower, The Landmark, 15 Queen's Road, Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中15號告羅士打大廈3002-3004室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BBS884',
#    'name': 'Auspicious Capital Management Limited',
#    'nameChi': '喜兆資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 2101  21/F Tower 6  The Gateway, 9 Canton Road, Tsim Sha Tsui, Hong Kong',
#     'fullAddressChin': '香港尖沙咀廣東道9號港威大廈第6座21樓2101室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BBT933',
#    'name': 'Abundancia Global Asset Management (Hong Kong) Limited',
#    'nameChi': '豐裕環球資產管理(香港)有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 1730, 17/F, Tower 2, Silvercord, 30 Canton Road, Tsim Sha Tsui, Kowloon, Hong Kong',
#     'fullAddressChin': 'Unit 1730, 17/F, Tower 2, Silvercord, 30 Canton Road, Tsim Sha Tsui, Kowloon, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BBX134',
#    'name': 'All-Stars Investment Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Suite 2103, 21/F, Two Exchange Square, 8 Connaught Place, Central, Hong Kong',
#     'fullAddressChin': '香港中環8康樂廣場交易廣場2期21樓2103室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BBY950',
#    'name': 'Arkkan Capital Management Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "23/F, 8 Queen's Road Central, Central, Hong Kong",
#     'fullAddressChin': "23/F, 8 Queen's Road Central, Central, Hong Kong",
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BBZ266',
#    'name': 'Atlantic Asset Management Limited',
#    'nameChi': '大西洋資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 1908, 19/F, Tower 2, Lippo Centre, 89 Queensway, Hong Kong',
#     'fullAddressChin': '香港金鐘道89號力寶中心2座19樓1908室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BCP239',
#    'name': 'APC Partners Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Block B Office 10 20/F Great Smart Tower, 230 Wanchai Road, Wanchai, Hong Kong',
#     'fullAddressChin': '香港灣仔灣仔道230號佳誠大廈B座20樓10室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BDD869',
#    'name': 'Arcus Investment Asia Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 100 5th Floor United Centre, 95 Queensway, Admiralty, Hong Kong',
#     'fullAddressChin': '香港金鐘金鐘道95號統一中心5樓100室',
# ...
#    'address': {'fullAddress': 'Office 2017, 20/F, Lee Garden 3, 1 Sunning Road, Causeway Bay, Hong Kong',
#     'fullAddressChin': '香港銅鑼灣新寧道1 號利園3期2017室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BRK187',
#    'name': 'Alphahill Capital Limited',
#    'nameChi': '明山資本有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Room 6623, 66/F The Center, 99 Queen's Road Central, Central, Hong Kong",
#     'fullAddressChin': '香港中環皇后大道中99 號中環中心66 樓6623 室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BRM616',
#    'name': 'Aeons Capital Management Limited',
#    'nameChi': '盛永資本管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 871, Level 8, Admiralty Centre Tower 2, 18 Harbour Road, Admiralty, Hong Kong',
#     'fullAddressChin': '香港金鐘夏慤道18號海富中心2座8樓871室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BRQ711',
#    'name': 'Astrapto Capital Partners (HK) Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit B, 10/F, Hong Kong Diamond Exchange Building, 8-10 Duddell Street, Central, Hong Kong',
#     'fullAddressChin': '香港中環都爹利街8-10號香港鑽石會大廈10樓B室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BRQ755',
#    'name': 'Arkimer Asset Management Limited',
#    'nameChi': '朝陽投資管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 3409, 34/F., AIA Tower, No. 183 Electric Road, North Point, Hong Kong',
#     'fullAddressChin': '香港北角電氣道183號友邦廣場34樓3409室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BRT453',
#    'name': 'ALLPRO ASSET MANAGEMENT LIMITED',
#    'nameChi': '諾一資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 01, 5/F, United Centre, 95 Queensway, Admiralty, Hong Kong, Hong Kong',
#     'fullAddressChin': 'Room 01, 5/F, United Centre, 95 Queensway, Admiralty, Hong Kong, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BRT581',
#    'name': 'Advance Asset Management Limited',
#    'nameChi': '領先資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '21/Floor, The Phoenix, 23 Luard Road, Wanchai, Hong Kong',
#     'fullAddressChin': '21/Floor, The Phoenix, 23 Luard Road, Wanchai, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BRV239',
#    'name': 'AP Capital Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'H2, 20/F MG Tower, 133 Hoi Bun Road, Kwun Tong Kowloon, Hong Kong',
#     'fullAddressChin': '香港九龍觀塘海濱道133號萬兆豐中心20樓H2',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BRY894',
#    'name': 'AI-SQUARED MANAGEMENT LIMITED',
#    'nameChi': '睿目投資管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 3610, ICBC Tower, 3 Garden Road, Central, Hong Kong, Hong Kong',
#     'fullAddressChin': 'Unit 3610, ICBC Tower, 3 Garden Road, Central, Hong Kong, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BSF767',
#    'name': 'Alpine Investment Management Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '3405-3406, Two Pacific Place, 88 Queensway, Admiralty, Hong Kong, Hong Kong',
#     'fullAddressChin': '香港金鐘, 香港太古廣埸二期, 金鐘道88 號3405-3406室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BSF946',
#    'name': 'Ahead Asset Management Limited ',
#    'nameChi': '正得資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '16/F C-Bons International Centre, 108 Wai Yip Street, Kwun Tong, Hong Kong',
#     'fullAddressChin': '香港觀塘偉業街108號絲寶國際大廈16棲',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BSG476',
#    'name': 'Alpha Sherpa Capital Management Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 501, 5/F, The L. Plaza, 367-375 Queens Road Central, Hong Kong',
#     'fullAddressChin': '香港西區上環The L Plaza 367-375 號皇后大道中5 樓501 室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BSH388',
#    'name': 'AY Asset Management (HK) Limited',
#    'nameChi': '安楹資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 03, 16/F, Convention Plaza Office Tower, 1 Harbour Road, Wanchai, Hong Kong',
#     'fullAddressChin': '香港灣仔港灣道1號會展中心 - 辦公室大樓16樓3室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BSJ366',
#    'name': 'Affluence Capital Limited',
#    'nameChi': '澤輝資本有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 3503, 35/F,, Infinitus Plaza, 199 Des Voeux Road Central, Sheung Wan, Hong Kong',
#     'fullAddressChin': 'Unit 3503, 35/F,, Infinitus Plaza, 199 Des Voeux Road Central, Sheung Wan, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BSJ821',
#    'name': 'Achieve Capital Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 3701, 37/F, Lee Garden One, 33 Hysan Avenue, Causeway Bay, Hong Kong',
#     'fullAddressChin': 'Room 3701, 37/F, Lee Garden One, 33 Hysan Avenue, Causeway Bay, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BSO621',
#    'name': 'Alpha Elephant Capital Management (Hong Kong) Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 1532, Level 15, Nexxus Building, 41 Connaught Road Central, Central, Hong Kong',
#     'fullAddressChin': '香港香港中環干諾道中41號盈置大廈15樓1532室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BSX558',
#    'name': 'Astroll Management Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '3508A, 35/F, Two Pacific Place, 88 Queensway, Admiralty, Hong Kong',
#     'fullAddressChin': '香港金鐘金鐘道88號太古廣場二座35樓3508A室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTD829',
#    'name': 'Audacy Ventures Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 1502, 15/F, Bank of America Tower, No. 12 Harcourt Road, Central, Hong Kong',
#     'fullAddressChin': 'Unit 1502, 15/F, Bank of America Tower, No. 12 Harcourt Road, Central, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTE421',
#    'name': 'Antects Asset Management Limited',
#    'nameChi': '知新資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Rm 38, Level 38, Infinitus Plaza, 199 Des Voeux Road, Central, Hong Kong',
#     'fullAddressChin': '香港香港德輔道中199號無限極廣場38樓38室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTE522',
#    'name': 'Asian Capital Asset Management Limited',
#    'nameChi': '卓亞資產管理有限公司',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'SUITE 1405-9, BANK OF AMERICA TOWER, 12 HARCOURT ROAD, CENTRAL, Hong Kong',
#     'fullAddressChin': 'SUITE 1405-9, BANK OF AMERICA TOWER, 12 HARCOURT ROAD, CENTRAL, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTE674',
#    'name': 'Alphalt Company Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Room 2118 Lee Garden 3, 1 Sunning Road, Causeway Bay, Hong Kong',
#     'fullAddressChin': '香港銅鑼灣新寧道1號利園期3樓2118室',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTE883',
#    'name': 'AMINA (Hong Kong) Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '15/F, Club Lusitano, 16 Ice House Street, Central, Hong Kong, Hong Kong',
#     'fullAddressChin': '15/F, Club Lusitano, 16 Ice House Street, Central, Hong Kong, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTF811',
#    'name': 'Amerinvest Fund Management Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "4B, 41 D'Aguilar Street, Central, Hong Kong",
#     'fullAddressChin': "4B, 41 D'Aguilar Street, Central, Hong Kong",
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTM567',
#    'name': 'Augventive Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': "Room 549, 5/F, K11 Atelier, 728 King's Road, Quarry Bay, Hong Kong, Hong Kong",
#     'fullAddressChin': "Room 549, 5/F, K11 Atelier, 728 King's Road, Quarry Bay, Hong Kong, Hong Kong",
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTT170',
#    'name': 'Atlas Square Partners (HK) Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 4470, Level 44, Champion Tower, 3 Garden Road, Central, Hong Kong, Hong Kong',
#     'fullAddressChin': 'Unit 4470, Level 44, Champion Tower, 3 Garden Road, Central, Hong Kong, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTT175',
#    'name': 'Atlascap Invest Limited',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': 'Unit 3808, Level 38, Infinitus Plaza, 199 Des Voeux Road Central, Sheung Wan, Hong Kong',
#     'fullAddressChin': 'Unit 3808, Level 38, Infinitus Plaza, 199 Des Voeux Road Central, Sheung Wan, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None},
#   {'ceref': 'BTT515',
#    'name': 'ANKAA CAPITAL LIMITED',
#    'nameChi': '\x00',
#    'entityName': None,
#    'entityOtherName': None,
#    'entityType': None,
#    'isIndi': False,
#    'isEo': False,
#    'isCorp': True,
#    'isRi': False,
#    'hasActiveLicence': 'Y',
#    'hasActiveLicenceAmlo': 'N',
#    'isActiveEo': None,
#    'address': {'fullAddress': '86/F, International Commerce Centre, 1 Austin Road West, Kowloon, Hong Kong, Hong Kong',
#     'fullAddressChin': '86/F, International Commerce Centre, 1 Austin Road West, Kowloon, Hong Kong, Hong Kong',
#     'addrPrin': 'Y',
#     'centralEntity': None},
#    'raDetails': None,
#    'raDetailsAmlo': None}]}

# %%
df = pd.DataFrame(response.json())

# %%
df
# Out:
#      totalCount                                              items
# 0           203  {'ceref': 'AAB444', 'name': 'Amundi Hong Kong ...
# 1           203  {'ceref': 'AAD350', 'name': 'Anglo Chinese Cor...
# 2           203  {'ceref': 'AAD365', 'name': 'Anglo Chinese Sec...
# 3           203  {'ceref': 'AAE950', 'name': 'abrdn Hong Kong L...
# 4           203  {'ceref': 'AAF157', 'name': 'Aisance Asset Man...
# ..          ...                                                ...
# 198         203  {'ceref': 'BTF811', 'name': 'Amerinvest Fund M...
# 199         203  {'ceref': 'BTM567', 'name': 'Augventive Limite...
# 200         203  {'ceref': 'BTT170', 'name': 'Atlas Square Part...
# 201         203  {'ceref': 'BTT175', 'name': 'Atlascap Invest L...
# 202         203  {'ceref': 'BTT515', 'name': 'ANKAA CAPITAL LIM...
#
# [203 rows x 2 columns]

# %%
items_expanded = df['items'].apply(pd.Series)
df = pd.concat([df.drop('items', axis=1), items_expanded], axis=1)
address_expanded = df['address'].apply(pd.Series)
df = pd.concat([df.drop('address', axis=1), address_expanded], axis=1)
df
# Out:
# C:\Users\Clive\AppData\Local\Temp\ipykernel_16996\947239473.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   address_expanded = df['address'].apply(pd.Series)
# C:\Users\Clive\AppData\Local\Temp\ipykernel_16996\947239473.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   address_expanded = df['address'].apply(pd.Series)
# C:\Users\Clive\AppData\Local\Temp\ipykernel_16996\947239473.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   address_expanded = df['address'].apply(pd.Series)
# C:\Users\Clive\AppData\Local\Temp\ipykernel_16996\947239473.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   address_expanded = df['address'].apply(pd.Series)
#      totalCount   ceref                                      name  \
# 0           203  AAB444                  Amundi Hong Kong Limited
# 1           203  AAD350  Anglo Chinese Corporate Finance, Limited
# 2           203  AAD365         Anglo Chinese Securities, Limited
# 3           203  AAE950                   abrdn Hong Kong Limited
# 4           203  AAF157          Aisance Asset Management Limited
# ..          ...     ...                                       ...
# 198         203  BTF811        Amerinvest Fund Management Limited
# 199         203  BTM567                        Augventive Limited
# 200         203  BTT170        Atlas Square Partners (HK) Limited
# 201         203  BTT175                   Atlascap Invest Limited
# 202         203  BTT515                     ANKAA CAPITAL LIMITED
#
#             nameChi entityName entityOtherName entityType  isIndi   isEo  \
# 0    東方匯理資產管理香港有限公司       None            None       None   False  False
# 1        英高財務顧問有限公司       None            None       None   False  False
# 2          英高證券有限公司       None            None       None   False  False
# 3          安本香港有限公司       None            None       None   False  False
# 4        君達資產管理有限公司       None            None       None   False  False
# ..              ...        ...             ...        ...     ...    ...
# 198                      None            None       None   False  False
# 199                      None            None       None   False  False
# 200                      None            None       None   False  False
# 201                      None            None       None   False  False
# 202                      None            None       None   False  False
#
#      isCorp   isRi hasActiveLicence hasActiveLicenceAmlo isActiveEo raDetails  \
# 0      True  False                Y                    N       None      None
# 1      True  False                Y                    N       None      None
# 2      True  False                Y                    N       None      None
# 3      True  False                Y                    N       None      None
# 4      True  False                Y                    N       None      None
# ..      ...    ...              ...                  ...        ...       ...
# 198    True  False                Y                    N       None      None
# 199    True  False                Y                    N       None      None
# 200    True  False                Y                    N       None      None
# 201    True  False                Y                    N       None      None
# 202    True  False                Y                    N       None      None
#
#     raDetailsAmlo                                        fullAddress  \
# 0            None  Suites 04-06, 32nd floor, Two Taikoo Place, Ta...
# 1            None  40/F Two Exchange Square, 8 Connaught Place, C...
# 2            None  40/F Two Exchange Square, 8 Connaught Place, C...
# 3            None  30/F LHT Tower, 31 Queen's Road Central, Centr...
# 4            None  Room 1704A Tower 2 Admiralty Center, 18 Harcou...
# ..            ...                                                ...
# 198          None        4B, 41 D'Aguilar Street, Central, Hong Kong
# 199          None  Room 549, 5/F, K11 Atelier, 728 King's Road, Q...
# 200          None  Unit 4470, Level 44, Champion Tower, 3 Garden ...
# 201          None  Unit 3808, Level 38, Infinitus Plaza, 199 Des ...
# 202          None  86/F, International Commerce Centre, 1 Austin ...
#
#                                        fullAddressChin addrPrin  centralEntity
# 0                    香港香港 鰂魚涌英皇道979號 太古坊太古坊二座32樓04-06室        Y            NaN
# 1                                 香港中環康樂廣場8號交易廣場第2座40樓        Y            NaN
# 2                                 香港中環康樂廣場8號交易廣場第2座40樓        Y            NaN
# 3                                 香港中環皇后大道中31號陸海通大廈30樓        Y            NaN
# 4                              香港金鐘夏愨道18號海富中心第2期1704A室        Y            NaN
# ..                                                 ...      ...            ...
# 198        4B, 41 D'Aguilar Street, Central, Hong Kong        Y            NaN
# 199  Room 549, 5/F, K11 Atelier, 728 King's Road, Q...        Y            NaN
# 200  Unit 4470, Level 44, Champion Tower, 3 Garden ...        Y            NaN
# 201  Unit 3808, Level 38, Infinitus Plaza, 199 Des ...        Y            NaN
# 202  86/F, International Commerce Centre, 1 Austin ...        Y            NaN
#
# [203 rows x 20 columns]

# %%
df.to_excel('sfc.xlsx', index=False)
