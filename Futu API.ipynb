# %%
from futu import *

# %%
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)
# Out:
# 2021-06-24 14:06:56,371 [open_context_base.py] _socket_reconnect_and_wait_ready:258: Start connecting: host=127.0.0.1; port=11111;
# 2021-06-24 14:06:56,372 [open_context_base.py] on_connected:349: Connected : conn_id=1;
# 2021-06-24 14:06:56,376 [open_context_base.py] _handle_init_connect:454: InitConnect ok: conn_id=1; info={'server_version': 217, 'login_user_id': 16588498, 'conn_id': 6813708992376458074, 'conn_key': 'D731DBAEBF93BC48', 'conn_iv': '68AD011B03E51250', 'keep_alive_interval': 10, 'is_encrypt': False};

# %%
ret_sub, err_message = quote_ctx.subscribe(['HK.00302'], [SubType.RT_DATA], subscribe_push=False)
# 先订阅分时数据类型。订阅成功后 FutuOpenD 将持续收到服务器的推送，False 代表暂时不需要推送给脚本

# %%
if ret_sub == RET_OK:   # 订阅成功
    ret, data = quote_ctx.get_rt_data('HK.00302')   # 获取一次分时数据
    if ret == RET_OK:
        print(data)
    else:
        print('error:', data)
else:
    print('subscription failed', err_message)
# Out:
#          code                 time  is_blank  opened_mins  cur_price  \
# 0    HK.00302  2021-06-24 09:30:00     False          570       3.67
# 1    HK.00302  2021-06-24 09:31:00     False          571       3.70
# 2    HK.00302  2021-06-24 09:32:00     False          572       3.73
# 3    HK.00302  2021-06-24 09:33:00     False          573       3.72
# 4    HK.00302  2021-06-24 09:34:00     False          574       3.70
# ..        ...                  ...       ...          ...        ...
# 214  HK.00302  2021-06-24 14:04:00     False          844       3.78
# 215  HK.00302  2021-06-24 14:05:00     False          845       3.80
# 216  HK.00302  2021-06-24 14:06:00     False          846       3.80
# 217  HK.00302  2021-06-24 14:07:00     False          847       3.80
# 218  HK.00302  2021-06-24 14:08:00     False          848       3.80
#
#      last_close  avg_price   volume    turnover
# 0          3.67   3.670000     2000      7340.0
# ...

# %%
data
# Out:
#          code                 time  is_blank  opened_mins  cur_price  \
# 0    HK.00302  2021-06-24 09:30:00     False          570       3.67
# 1    HK.00302  2021-06-24 09:31:00     False          571       3.70
# 2    HK.00302  2021-06-24 09:32:00     False          572       3.73
# 3    HK.00302  2021-06-24 09:33:00     False          573       3.72
# 4    HK.00302  2021-06-24 09:34:00     False          574       3.70
# ..        ...                  ...       ...          ...        ...
# 214  HK.00302  2021-06-24 14:04:00     False          844       3.78
# 215  HK.00302  2021-06-24 14:05:00     False          845       3.80
# 216  HK.00302  2021-06-24 14:06:00     False          846       3.80
# 217  HK.00302  2021-06-24 14:07:00     False          847       3.80
# 218  HK.00302  2021-06-24 14:08:00     False          848       3.80
#
#      last_close  avg_price   volume    turnover
# 0          3.67   3.670000     2000      7340.0
# ...

# %%
data.to_excel('302_realtime.xlsx')

# %%
quote_ctx.close()   # 关闭当条连接，FutuOpenD 会在1分钟后自动取消相应股票相应类型的订阅

# %%
from futu import *
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)

ret_sub, err_message = quote_ctx.subscribe(['HK.00302'], [SubType.TICKER], subscribe_push=False)
# 先订阅逐笔类型。订阅成功后 FutuOpenD 将持续收到服务器的推送，False 代表暂时不需要推送给脚本
if ret_sub == RET_OK:  # 订阅成功
    ret, data = quote_ctx.get_rt_ticker('HK.00302', 10000)  # 获取港股00700最近2个逐笔
    if ret == RET_OK:
        print(data)
        print(data['turnover'][0])   # 取第一条的成交金额
        print(data['turnover'].values.tolist())   # 转为 list
    else:
        print('error:', data)
else:
    print('subscription failed', err_message)
quote_ctx.close()  # 关闭当条连接，FutuOpenD 会在1分钟后自动取消相应股票相应类型的订阅
# Out:
# 2021-06-24 16:06:22,838 [open_context_base.py] _socket_reconnect_and_wait_ready:258: Start connecting: host=127.0.0.1; port=11111;
# 2021-06-24 16:06:22,839 [open_context_base.py] on_connected:349: Connected : conn_id=5;
# 2021-06-24 16:06:22,843 [open_context_base.py] _handle_init_connect:454: InitConnect ok: conn_id=5; info={'server_version': 504, 'login_user_id': 16588498, 'conn_id': 6813739050710975952, 'conn_key': 'CE5A92D9BF9328B7', 'conn_iv': '02000165B2F541E1', 'keep_alive_interval': 10, 'is_encrypt': False};
#          code                 time  price  volume  turnover ticker_direction  \
# 0    HK.00302  2021-06-24 11:06:16   3.76    8000   30080.0              BUY
# 1    HK.00302  2021-06-24 11:06:40   3.76   60000  225600.0              BUY
# 2    HK.00302  2021-06-24 11:06:44   3.76   10000   37600.0              BUY
# 3    HK.00302  2021-06-24 11:07:12   3.76   20000   75200.0              BUY
# ...

# %%
data.to_excel('302_rt_ticker.xlsx')

# %%
from futu import *
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)
ret_sub, err_message = quote_ctx.subscribe(['HK.00302'], [SubType.RT_DATA], subscribe_push=False)
# 先订阅分时数据类型。订阅成功后 FutuOpenD 将持续收到服务器的推送，False 代表暂时不需要推送给脚本
if ret_sub == RET_OK:   # 订阅成功
    ret, data = quote_ctx.get_rt_data('HK.00302')   # 获取一次分时数据
    if ret == RET_OK:
        print(data)
    else:
        print('error:', data)
else:
    print('subscription failed', err_message)
quote_ctx.close()   # 关闭当条连接，FutuOpenD 会在1分钟后自动取消相应股票相应类型的订阅
# Out:
# 2021-06-24 16:28:49,815 [open_context_base.py] _socket_reconnect_and_wait_ready:258: Start connecting: host=127.0.0.1; port=11111;
# 2021-06-24 16:28:49,817 [open_context_base.py] on_connected:349: Connected : conn_id=8;
# 2021-06-24 16:28:49,821 [open_context_base.py] _handle_init_connect:454: InitConnect ok: conn_id=8; info={'server_version': 504, 'login_user_id': 16588498, 'conn_id': 6813744700347498932, 'conn_key': '19AE99E1BF9324A6', 'conn_iv': '2373423671F6110C', 'keep_alive_interval': 10, 'is_encrypt': False};
#          code                 time  is_blank  opened_mins  cur_price  \
# 0    HK.00302  2021-06-24 09:30:00     False          570       3.67
# 1    HK.00302  2021-06-24 09:31:00     False          571       3.70
# 2    HK.00302  2021-06-24 09:32:00     False          572       3.73
# 3    HK.00302  2021-06-24 09:33:00     False          573       3.72
# 4    HK.00302  2021-06-24 09:34:00     False          574       3.70
# ...

# %%
data.to_excel('302-minute.xlsx')

# %%
from futu import *
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)

ret_sub, err_message = quote_ctx.subscribe(['HK.00302'], [SubType.K_30M], subscribe_push=False)
# 先订阅 K 线类型。订阅成功后 FutuOpenD 将持续收到服务器的推送，False 代表暂时不需要推送给脚本
if ret_sub == RET_OK:  # 订阅成功
    ret, data = quote_ctx.get_cur_kline('HK.00302', 1000, SubType.K_30M, AuType.QFQ)  # 获取港股00700最近2个 K 线数据
    if ret == RET_OK:
        print(data)
        print(data['turnover_rate'][0])   # 取第一条的换手率
        print(data['turnover_rate'].values.tolist())   # 转为 list
    else:
        print('error:', data)
else:
    print('subscription failed', err_message)
quote_ctx.close()  # 关闭当条连接，FutuOpenD 会在1分钟后自动取消相应股票相应类型的订阅
# Out:
# 2021-06-24 16:37:14,028 [open_context_base.py] _socket_reconnect_and_wait_ready:258: Start connecting: host=127.0.0.1; port=11111;
# 2021-06-24 16:37:14,029 [open_context_base.py] on_connected:349: Connected : conn_id=14;
# 2021-06-24 16:37:14,031 [open_context_base.py] _handle_init_connect:454: InitConnect ok: conn_id=14; info={'server_version': 504, 'login_user_id': 16588498, 'conn_id': 6813746815167257188, 'conn_key': '950B9BE4BF93C065', 'conn_iv': '0E29E5A4BCF6F150', 'keep_alive_interval': 10, 'is_encrypt': False};
#          code             time_key    open   close    high     low    volume  \
# 0    HK.00302  2021-02-08 14:00:00  3.4572  3.4072  3.4572  3.4072   1670000
# 1    HK.00302  2021-02-08 14:30:00  3.4172  3.4272  3.4272  3.4072   1608000
# 2    HK.00302  2021-02-08 15:00:00  3.4072  3.4372  3.4372  3.4072    932000
# 3    HK.00302  2021-02-08 15:30:00  3.4372  3.4372  3.4472  3.4272    850000
# ...

# %%
data.to_excel('302-30M-OHLC.xlsx')

# %%
from futu import *
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)

ret, data = quote_ctx.get_plate_list(Market.HK, Plate.CONCEPT)
if ret == RET_OK:
    print(data)
    print(data['plate_name'][0])    # 取第一条的板块名称
    print(data['plate_name'].values.tolist())   # 转为 list
else:
    print('error:', data)
quote_ctx.close() # 结束后记得关闭当条连接，防止连接条数用尽
# Out:
# 2021-06-24 16:57:18,350 [open_context_base.py] _socket_reconnect_and_wait_ready:258: Start connecting: host=127.0.0.1; port=11111;
# 2021-06-24 16:57:18,352 [open_context_base.py] on_connected:349: Connected : conn_id=20;
# 2021-06-24 16:57:18,355 [open_context_base.py] _handle_init_connect:454: InitConnect ok: conn_id=20; info={'server_version': 504, 'login_user_id': 16588498, 'conn_id': 6813751866465067575, 'conn_key': 'FEB2C8EBBF9338E5', 'conn_iv': 'C83A250C65F72187', 'keep_alive_interval': 10, 'is_encrypt': False};
#           code plate_name plate_id
# 0    HK.BK1000      做空集合股   BK1000
# 1    HK.BK1110      阿里概念股   BK1110
# 2    HK.BK1161        双十一   BK1161
# 3    HK.BK1165      雄安概念股   BK1165
# 4    HK.BK1166       苹果概念   BK1166
# ..         ...        ...      ...
# 101  HK.BK1994      香港零售股   BK1994
# 102  HK.BK1995        区块链   BK1995
# 103  HK.BK1996       猪肉概念   BK1996
# 104  HK.BK1998      节假日概念   BK1998
# 105  HK.BK1999       殡葬概念   BK1999
#
# [106 rows x 3 columns]
# ...

# %%
data.to_excel('板块列表.xlsx')
