# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# first attempt - only table header is scraped, content is not there

# %%
url = 'https://www.edr.hk/search-all'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
table = soup.select('table.dataTable')

# %%
table
# Out:
# [<table class="dataTable table dt-responsive" id="doctor-table">
#  <thead>
#  <tr>
#  <th></th>
#  <th>醫生姓名</th>
#  <th>性別</th>
#  <th>註冊專科</th>
#  <th>執業性質</th>
#  <th>地址</th>
#  <th>地區</th>
#  <th>電話</th>
#  </tr>
#  </thead>
#  <tbody></tbody>
#  </table>]

# %% [markdown]
# second attempt - adding query parameters to the URL, can get 20 results (one page) in json format

# %%
# specify 註冊專科 = "西醫、普通科" in the URL
url = 'https://www.edr.hk/ajax/search-all?draw=2&columns%5B0%5D%5Bdata%5D=&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=false&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=false&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=false&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=false&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=doctor%2Cgeneral-practice&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=false&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=address_chi&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=false&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=district&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=false&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B7%5D%5Bdata%5D=phone&columns%5B7%5D%5Bname%5D=&columns%5B7%5D%5Bsearchable%5D=true&columns%5B7%5D%5Borderable%5D=false&columns%5B7%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B7%5D%5Bsearch%5D%5Bregex%5D=false&start=0&length=20&search%5Bvalue%5D=&search%5Bregex%5D=false&_=1676908785800'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
results = response.json()
results
# Out:
# {'draw': '2',
#  'recordsTotal': 11380,
#  'recordsFiltered': 2663,
#  'data': [{'name_chi': '鄭寶儀',
#    'name_eng': 'Cheng Po Yi, Priscilla',
#    'gender': '女',
#    'practice': '私人執業',
#    'address_chi': '九龍尖沙咀彌敦道132號美麗華廣場A座12樓1208-1209室',
#    'district': '油尖旺',
#    'phone': '35778822',
#    'voucher': False,
#    'ppi': False,
#    'ehealth': False,
#    'ecard': True,
#    'night': False,
#    'speciality_name_chi': '西醫',
#    'sub_speciality_name_chi': '普通科',
#    'doctor_title_chi': '醫生',
#    'url': '/doctor/info/cheng-po-yi-priscilla-b'},
#   {'name_chi': '鄭寶儀',
#    'name_eng': 'Cheng Po Yi, Priscilla',
#    'gender': '女',
#    'practice': '私人執業',
#    'address_chi': '香港銅鑼灣軒尼詩道449號地庫全層',
#    'district': '灣仔',
#    'phone': '28366288',
#    'voucher': False,
#    'ppi': False,
#    'ehealth': False,
#    'ecard': True,
#    'night': False,
#    'speciality_name_chi': '西醫',
#    'sub_speciality_name_chi': '普通科',
#    'doctor_title_chi': '醫生',
# ...

# %%
results['data'][0]
# Out:
# {'name_chi': '鄭寶儀',
#  'name_eng': 'Cheng Po Yi, Priscilla',
#  'gender': '女',
#  'practice': '私人執業',
#  'address_chi': '九龍尖沙咀彌敦道132號美麗華廣場A座12樓1208-1209室',
#  'district': '油尖旺',
#  'phone': '35778822',
#  'voucher': False,
#  'ppi': False,
#  'ehealth': False,
#  'ecard': True,
#  'night': False,
#  'speciality_name_chi': '西醫',
#  'sub_speciality_name_chi': '普通科',
#  'doctor_title_chi': '醫生',
#  'url': '/doctor/info/cheng-po-yi-priscilla-b'}

# %%
len(results['data'])
# Out:
# 20

# %%
pd.DataFrame(results['data']).head()
# Out:
#   name_chi                name_eng gender practice  \
# 0      鄭寶儀  Cheng Po Yi, Priscilla      女     私人執業
# 1      鄭寶儀  Cheng Po Yi, Priscilla      女     私人執業
# 2      李善章         Lee Shin Cheung      男     私人執業
# 3      余衛祖     Yu Wai Cho, Michael      男     私人執業
# 4      郭繩武    Kwok Sing Woo, Simon      男     私人執業
#
#                         address_chi district     phone  voucher    ppi  \
# 0  九龍尖沙咀彌敦道132號美麗華廣場A座12樓1208-1209室      油尖旺  35778822    False  False
# 1                 香港銅鑼灣軒尼詩道449號地庫全層       灣仔  28366288    False  False
# 2                      新界元朗安寧路51號地下       元朗  22745198     True  False
# 3              香港鴨脷洲海怡半島東商場G60-61地舖       南區  25183230     True  False
# 4                香港柴灣道350號樂軒臺307號舖        東區  25571232    False  False
#
#    ehealth  ecard  night speciality_name_chi sub_speciality_name_chi  \
# 0    False   True  False                  西醫                     普通科
# 1    False   True  False                  西醫                     普通科
# ...

# %% [markdown]
# third attempt - change the 'length' paramter to get all results

# %%
url = 'https://www.edr.hk/ajax/search-all?draw=2&columns%5B0%5D%5Bdata%5D=&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=false&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=false&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=false&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=false&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=doctor%2Cgeneral-practice&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=false&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=address_chi&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=false&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=district&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=false&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B7%5D%5Bdata%5D=phone&columns%5B7%5D%5Bname%5D=&columns%5B7%5D%5Bsearchable%5D=true&columns%5B7%5D%5Borderable%5D=false&columns%5B7%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B7%5D%5Bsearch%5D%5Bregex%5D=false&start=0&length=2663&search%5Bvalue%5D=&search%5Bregex%5D=false&_=1676908785800'

# %%
response = requests.get(url)
results = response.json()
df = pd.DataFrame(results['data'])

# %%
len(df)
# Out:
# 2663

# %%
df.tail()
# Out:
#      name_chi                       name_eng gender practice  \
# 2658      余為康                    Yu Wai Hong      男     私人執業
# 2659      陳樂詩            CHAN LOK SZE, CANDY      女     私人執業
# 2660      陳志強                 Chan Chi Keung      男     私人執業
# 2661      陳榮超                 CHAN WING CHIU      男     私人執業
# 2662      曾文宗  Myint Thein @ Chan Boon Chong      男     私人執業
#
#                     address_chi district     phone  voucher    ppi  ehealth  \
# 2658  香港堅尼地城士美非路41A-43號美非閣地下2號舖      中西區  28161631    False  False    False
# 2659                 香港仔洛陽街1號地下       南區  25251730    False  False    False
# 2660         香港筲箕灣愛蝶灣愛東商場地下19號舖       東區  31964076    False  False    False
# 2661             九龍秀茂坪曉麗苑商場201室       觀塘  23400006     True  False    False
# 2662            九龍窩打老道92號金碧大廈7B      九龍城  27132842    False  False    False
#
#       ecard  night speciality_name_chi sub_speciality_name_chi  \
# 2658  False  False                  西醫                     普通科
# ...

# %%
df.to_excel('doctors.xlsx')
