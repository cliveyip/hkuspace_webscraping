# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.openrice.com/zh/hongkong/restaurants?where=荃灣&page=1'

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36"
response = requests.get(url, headers={'User-Agent': user_agent})
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
resto_list = soup.select('h2.title-name>a')

resto_list
# Out:
# [<a data-ga-event='[{"category":"SR2 Source","action":".get-poi","label":"CityID:0;PoiId:752746","value":null}]' data-impression='{"FeatureItemId":28974,"ItemId":0,"ChannelId":23,"SubChannelId":1,"RegionId":0}' href="/zh/hongkong/r-%E9%A6%99%E6%B1%9F%E8%8A%B1%E6%9C%88-%E8%8D%83%E7%81%A3-%E6%B8%AF%E5%BC%8F-%E7%81%AB%E9%8D%8B-r752746">香江花月 (荃灣廣場) Victorian Era (Tsuen Wan Plaza)</a>,
#  <a data-ga-event='[{"category":"SR2 Source","action":".get-poi","label":"CityID:0;PoiId:752592","value":null}]' data-impression='{"FeatureItemId":28986,"ItemId":0,"ChannelId":23,"SubChannelId":1,"RegionId":0}' href="/zh/hongkong/r-%E5%92%8C%E7%89%9B%E7%87%92%E8%82%89%E4%B8%80%E9%83%8E-%E8%8D%83%E7%81%A3-%E6%97%A5%E6%9C%AC%E8%8F%9C-%E6%97%A5%E5%BC%8F%E6%94%BE%E9%A1%8C-r752592">和牛燒肉一郎 (荃灣廣場) Wagyu Yakiniku Ichiro (Tsuen Wan Plaza)</a>,
# ...

# %%
for i,resto in enumerate(resto_list):
      resto_list[i] = resto.text

print(resto_list)
# Out:
# ['香江花月 (荃灣廣場) Victorian Era (Tsuen Wan Plaza)', '和牛燒肉一郎 (荃灣廣場) Wagyu Yakiniku Ichiro (Tsuen Wan Plaza)', 'Ann Mamma Thai kitchen by 張秀玲', '初見 Shoken', '牛大人台灣火鍋吃到飽 (大鴻輝(荃灣)中心) Master Beef (Tai Hung Fai Tsuen Wan Centre)', 'Peko Peko Eatery (海之戀商場) Peko Peko Eatery (OP Mall)', 'Vision 8', '古今二 (荃灣千色匯) KOKON2 (Kolour Tsuen Wan)', '安平燒肉 Aping Grill', '麻辣風雲 (荃碧大廈) Spicy Restaurant (Tsuen Bik Building)', '18樓雞煲火鍋專門店', 'Deer Kitchen (荃新天地)', '鳥山名 Toriyamana', '雲家小鍋米線 (328廣場) Wenger Noodle (328 Plaza)', 'Espresso Alchemy', 'WM Café & Bar (海之戀商場)', 'The BASE nature']

# %%
url = 'https://www.openrice.com/api/pois?uiLang=zh&uiCity=hongkong&page=17&&sortBy=Default&where=%E8%8D%83%E7%81%A3'

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36"
response = requests.get(url, headers={'User-Agent': user_agent})

# %%
response.json()
# Out:
# {'searchResult': {'paginationResult': {'closedCount': 0,
#    'isBookmarkedResult': False,
#    'isFarThanMaximum': False,
#    'results': [{'index': 0,
#      'categoriesUI': [{'urlUI': '/zh/hongkong/restaurants/cuisine/%E6%97%A5%E6%9C%AC%E8%8F%9C',
#        'searchKey': 'cuisineId=2009',
#        'categoryId': 2009,
#        'categoryTypeId': 1,
#        'regionId': 0,
#        'name': '日本菜',
#        'callName': '日本菜',
#        'status': 0,
#        'searchStart': 0,
#        'searchEnd': 0,
#        'sortOrder': 0},
#       {'urlUI': '/zh/hongkong/restaurants/dish/%E7%87%92%E7%83%A4',
#        'searchKey': 'dishId=1019',
#        'categoryId': 1019,
#        'categoryTypeId': 2,
#        'regionId': 0,
#        'name': '燒烤',
#        'callName': '燒烤',
#        'status': 0,
#        'searchStart': 0,
#        'searchEnd': 0,
#        'sortOrder': 0}],
#      'isMoreThan2CatUI': True,
#      'coupons': [],
# ...
