# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ### scrape one stock

# %% [markdown]
# send request without user agent

# %%
url = 'https://finance.yahoo.com/quote/AAPL/sustainability'
response = requests.get(url)
response
# Out:
# <Response [404]>

# %%
response.request.headers
# Out:
# {'User-Agent': 'python-requests/2.28.2', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %% [markdown]
# sent request with user agent

# %%
url = 'https://finance.yahoo.com/quote/AAPL/sustainability'
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
response = requests.get(url, headers={'User-Agent': user_agent} )
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# option 1: use soup.select

# %%
ESG_risk_score = soup.select("div.Fz\\(36px\\).Fw\\(600\\).D\\(ib\\).Mend\\(5px\\)")
print('Total ESG Risk Score is: ', ESG_risk_score[0].text)
# Out:
# Total ESG Risk Score is:  17

# %% [markdown]
# option 2: use soup.find_all

# %%
ESG_risk_score = soup.find_all('div', {'class':'Fz(36px) Fw(600) D(ib) Mend(5px)'})
print('Total ESG Risk Score is: ', ESG_risk_score[0].text)
# Out:
# Total ESG Risk Score is:  17

# %% [markdown]
# option 3: use soup.find

# %%
ESG_risk_score = soup.find('div', {'class':'Fz(36px) Fw(600) D(ib) Mend(5px)'})
print('Total ESG Risk Score is: ', ESG_risk_score.text)
# Out:
# Total ESG Risk Score is:  17

# %% [markdown]
# ### scrape many stocks

# %% [markdown]
# create function for parsing yahoo finance page to get ESG scores

# %%
def parse_soup(soup):
    
    esg_score = soup.find('div', {'class':'Fz(36px) Fw(600) D(ib) Mend(5px)'})
    other_scores = soup.find_all('div', {'class':'D(ib) Fz(23px) smartphone_Fz(22px) Fw(600)'})
    ctr_score = soup.find('div', {'class':'D(ib) Fz(36px) Fw(500)'})
    
    # ESG score may be unavailable for some tickers 
    # e.g. https://finance.yahoo.com/quote/alk/sustainability

    if esg_score is None:
        esg_score = 'N/A'
    else:
        esg_score = esg_score.text
        
    if ctr_score is None:
        ctr_score = 'N/A'
    else:
        ctr_score = ctr_score.text
        
    if len(other_scores) == 0:
        env_score = 'N/A'
        soc_score = 'N/A'
        gov_score = 'N/A'
    else:
        env_score = other_scores[0].text
        soc_score = other_scores[1].text
        gov_score = other_scores[2].text
        
    return [esg_score, env_score, soc_score, gov_score, ctr_score]

# %% [markdown]
# get ticker list from wikipedia

# %%
wiki_page = requests.get('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies').text
sp_500 = pd.read_html(wiki_page)

# %%
tickers = sp_500[0]['Symbol'].to_list()
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BG',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
#  'CDAY',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'CEG',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'CSGP',
#  'COST',
#  'CTRA',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DISH',
#  'DIS',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DTE',
#  'DUK',
#  'DD',
#  'DXC',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'ELV',
#  'LLY',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EQT',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'ETSY',
#  'RE',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FICO',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FITB',
#  'FRC',
#  'FSLR',
#  'FE',
#  'FIS',
#  'FISV',
#  'FLT',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GRMN',
#  'IT',
#  'GEHC',
#  'GEN',
#  'GNRC',
#  'GD',
#  'GE',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GL',
#  'GPN',
#  'GS',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'PEAK',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'ILMN',
#  'INCY',
#  'IR',
#  'PODD',
#  'INTC',
#  'ICE',
#  'IFF',
#  'IP',
#  'IPG',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'INVH',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'K',
#  'KDP',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LNC',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LYB',
#  'MTB',
#  'MRO',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'META',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'MOH',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NWL',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NKE',
#  'NI',
#  'NDSN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'ON',
#  'OKE',
#  'ORCL',
#  'OGN',
#  'OTIS',
#  'PCAR',
#  'PKG',
#  'PARA',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PNR',
#  'PEP',
#  'PKI',
#  'PFE',
#  'PCG',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RHI',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SEE',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SNA',
#  'SEDG',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STLD',
#  'STE',
#  'SYK',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TRGP',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TYL',
#  'TSN',
#  'USB',
#  'UDR',
#  'ULTA',
#  'UNP',
#  'UAL',
#  'UPS',
#  'URI',
#  'UNH',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VFC',
#  'VTRS',
#  'VICI',
#  'V',
#  'VMC',
#  'WAB',
#  'WBA',
#  'WMT',
#  'WBD',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WTW',
#  'GWW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %% [markdown]
# loop through all the tickers (note: the list is long, you may want to test with a smaller sample first e.g. tickers[:10] for first 10 tickers

# %%
scores_list = []
for ticker in tickers:
    url = 'https://finance.yahoo.com/quote/'+ ticker + '/sustainability'
    print(url) # for debugging
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
    response = requests.get(url, headers={'User-Agent': user_agent})
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        scores = parse_soup(soup)
        scores.insert(0, ticker)
        scores_list.append(scores)
# Out:
# https://finance.yahoo.com/quote/MMM/sustainability
# https://finance.yahoo.com/quote/AOS/sustainability
# https://finance.yahoo.com/quote/ABT/sustainability
# https://finance.yahoo.com/quote/ABBV/sustainability
# https://finance.yahoo.com/quote/ACN/sustainability
# https://finance.yahoo.com/quote/ATVI/sustainability
# https://finance.yahoo.com/quote/ADM/sustainability
# https://finance.yahoo.com/quote/ADBE/sustainability
# https://finance.yahoo.com/quote/ADP/sustainability
# https://finance.yahoo.com/quote/AAP/sustainability
# https://finance.yahoo.com/quote/AES/sustainability
# https://finance.yahoo.com/quote/AFL/sustainability
# https://finance.yahoo.com/quote/A/sustainability
# https://finance.yahoo.com/quote/APD/sustainability
# https://finance.yahoo.com/quote/AKAM/sustainability
# https://finance.yahoo.com/quote/ALK/sustainability
# https://finance.yahoo.com/quote/ALB/sustainability
# https://finance.yahoo.com/quote/ARE/sustainability
# https://finance.yahoo.com/quote/ALGN/sustainability
# https://finance.yahoo.com/quote/PFG/sustainability
# https://finance.yahoo.com/quote/PG/sustainability
# https://finance.yahoo.com/quote/PGR/sustainability
# https://finance.yahoo.com/quote/PLD/sustainability
# https://finance.yahoo.com/quote/PRU/sustainability
# https://finance.yahoo.com/quote/PEG/sustainability
# https://finance.yahoo.com/quote/PTC/sustainability
# https://finance.yahoo.com/quote/PSA/sustainability
# https://finance.yahoo.com/quote/PHM/sustainability
# https://finance.yahoo.com/quote/QRVO/sustainability
# https://finance.yahoo.com/quote/PWR/sustainability
# https://finance.yahoo.com/quote/QCOM/sustainability
# https://finance.yahoo.com/quote/DGX/sustainability
# https://finance.yahoo.com/quote/RL/sustainability
# https://finance.yahoo.com/quote/RJF/sustainability
# https://finance.yahoo.com/quote/RTX/sustainability
# https://finance.yahoo.com/quote/O/sustainability
# https://finance.yahoo.com/quote/REG/sustainability
# https://finance.yahoo.com/quote/REGN/sustainability
# https://finance.yahoo.com/quote/RF/sustainability
# https://finance.yahoo.com/quote/RSG/sustainability
# https://finance.yahoo.com/quote/RMD/sustainability
# https://finance.yahoo.com/quote/RHI/sustainability
# https://finance.yahoo.com/quote/ROK/sustainability
# https://finance.yahoo.com/quote/ROL/sustainability
# https://finance.yahoo.com/quote/ROP/sustainability
# https://finance.yahoo.com/quote/ROST/sustainability
# https://finance.yahoo.com/quote/RCL/sustainability
# https://finance.yahoo.com/quote/SPGI/sustainability
# https://finance.yahoo.com/quote/CRM/sustainability
# https://finance.yahoo.com/quote/SBAC/sustainability
# https://finance.yahoo.com/quote/SLB/sustainability
# https://finance.yahoo.com/quote/STX/sustainability
# https://finance.yahoo.com/quote/SEE/sustainability
# https://finance.yahoo.com/quote/SRE/sustainability
# https://finance.yahoo.com/quote/NOW/sustainability
# https://finance.yahoo.com/quote/SHW/sustainability
# https://finance.yahoo.com/quote/SPG/sustainability
# https://finance.yahoo.com/quote/SWKS/sustainability
# https://finance.yahoo.com/quote/SJM/sustainability
# https://finance.yahoo.com/quote/SNA/sustainability
# https://finance.yahoo.com/quote/SEDG/sustainability
# https://finance.yahoo.com/quote/SO/sustainability
# https://finance.yahoo.com/quote/LUV/sustainability
# https://finance.yahoo.com/quote/SWK/sustainability
# https://finance.yahoo.com/quote/SBUX/sustainability
# https://finance.yahoo.com/quote/STT/sustainability
# https://finance.yahoo.com/quote/STLD/sustainability
# https://finance.yahoo.com/quote/STE/sustainability
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_58124\1638740175.py in <module>
#       4     print(url) # for debugging
#       5     user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
# ----> 6     response = requests.get(url, headers={'User-Agent': user_agent})
#       7     if response.status_code == 200:
#       8         soup = BeautifulSoup(response.text, 'html.parser')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     743
#     744         if not stream:
# --> 745             r.content
#     746
#     747         return r
#
# ~\anaconda3\lib\site-packages\requests\models.py in content(self)
#     897                 self._content = None
#     898             else:
# --> 899                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     900
#     901         self._content_consumed = True
#
# ~\anaconda3\lib\site-packages\requests\models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     621         """
#     622         if self.chunked and self.supports_chunked_reads():
# --> 623             for line in self.read_chunked(amt, decode_content=decode_content):
#     624                 yield line
#     625         else:
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     816                 if self.chunk_left == 0:
#     817                     break
# --> 818                 chunk = self._handle_chunk(amt)
#     819                 decoded = self._decode(
#     820                     chunk, decode_content=decode_content, flush_decoder=False
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _handle_chunk(self, amt)
#     760             self.chunk_left = None
#     761         elif amt < self.chunk_left:
# --> 762             value = self._fp._safe_read(amt)
#     763             self.chunk_left = self.chunk_left - amt
#     764             returned_chunk = value
#
# ~\anaconda3\lib\http\client.py in _safe_read(self, amt)
#     624         s = []
#     625         while amt > 0:
# --> 626             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     627             if not chunk:
#     628                 raise IncompleteRead(b''.join(s), amt)
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
scores_list

# %%
df_scores = pd.DataFrame(scores_list, columns=['Ticker', 'ESG_Score', 'Env_Score', 'Soc_Score', 'Gov_score', 'Ctr_score'])

# %%
df_scores
# Out:
#     Ticker ESG_Score Env_Score Soc_Score Gov_score Ctr_score
# 0      MMM        34      12.3      13.6       7.7         3
# 1      AOS        25       7.3      11.9       6.3         0
# 2      ABT        25       3.0      13.6       8.4         3
# 3     ABBV        28       1.1      16.8       9.9         3
# 4      ACN        10       0.3       4.6       4.8         2
# ..     ...       ...       ...       ...       ...       ...
# 425    LUV        32        11        15         6         2
# 426    SWK        26         6        13         8         2
# 427   SBUX        25         6        14         4         3
# 428    STT        22         2        11         9         2
# 429   STLD        32        10        14         8         1
#
# [430 rows x 6 columns]

# %%
df_scores.to_excel('ESG scores.xlsx', index=False)
